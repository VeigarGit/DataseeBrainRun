# %% [markdown]
# | Criação da leitura e mapeamento dos dados de 1 json |

# %%
import pandas as pd
import json
import glob
import os
from pandas.io.json import json_normalize

f = open('sensors/00qhiaz_1542975441749.json')
data = json.load(f)
with open('sensors/00qhiaz_1542975441749.json', 'r') as json_data:
   gay = json.load(json_data)

# %%
json_string = json.dumps(data)

# %% [markdown]
# | Printar Json na tela |

# %%
data

# %% [markdown]
# | Usar normalize para verificar parametros/tipos de label do json |
#
# Dataset divido em :
#
# player_id	: id
#
# accelerometer	: z,x,y, screen
#
# gyroscope	: z,x,y, screen
#
# deviceMotion	: z,x,y, screen
#
# magnetometer : z,x,y, screen

# %%
x = json_normalize(data)
x
# Out:
# C:\Users\rafav\AppData\Local\Temp\ipykernel_10404\3815656361.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   x = json_normalize(data)
#   player_id                                      accelerometer  \
# 0   0c87n4d  [{'z': -0.051025390625, 'y': 0.99267578125, 'x...
#
#                                            gyroscope  \
# 0  [{'z': -0.01038470957428217, 'y': -0.024434609...
#
#                                         deviceMotion  \
# 0  [{'accelerationIncludingGravity': {'z': 0.2782...
#
#                                         magnetometer
# 0  [{'z': 6.899999618530273, 'y': -35.39999771118...

# %% [markdown]
# | Verificar quais dados são passados mudando por tipo do parametro solicitado, não são os mesmos. |
#
# criação de 1 data frame unico para visualização por camadas/ quantidade de dados
#
# No exemplo são tirados 197 dados em cada parametroata

# %%
df = pd.DataFrame(data['accelerometer'])
df
# Out:
#             z         y         x          screen
# 0    0.598633  0.822266  0.037109  RegisterScreen
# 1    0.576172  0.825195  0.039062  RegisterScreen
# 2    0.584961  0.826172  0.024414  RegisterScreen
# 3    0.592773  0.821289  0.030273  RegisterScreen
# 4    0.571289  0.816406  0.029297  RegisterScreen
# ..        ...       ...       ...             ...
# 189  0.663086  0.760742 -0.020508  RegisterScreen
# 190  0.654297  0.752930 -0.023438  RegisterScreen
# 191  0.666992  0.742188 -0.011719  RegisterScreen
# 192  0.666016  0.749023 -0.023438  RegisterScreen
# 193  0.663086  0.743164 -0.012695  RegisterScreen
#
# [194 rows x 4 columns]

# %%
for i in data['accelerometer']:
    print(i)
# Out:
# {'z': 0.5986328125, 'y': 0.822265625, 'x': 0.037109375, 'screen': 'RegisterScreen'}
# {'z': 0.576171875, 'y': 0.8251953125, 'x': 0.0390625, 'screen': 'RegisterScreen'}
# {'z': 0.5849609375, 'y': 0.826171875, 'x': 0.0244140625, 'screen': 'RegisterScreen'}
# {'z': 0.5927734375, 'y': 0.8212890625, 'x': 0.03027343936264515, 'screen': 'RegisterScreen'}
# {'z': 0.5712890625, 'y': 0.81640625, 'x': 0.02929687313735485, 'screen': 'RegisterScreen'}
# {'z': 0.609375, 'y': 0.8125, 'x': 0.046875, 'screen': 'RegisterScreen'}
# {'z': 0.560546875, 'y': 0.8173828125, 'x': 0.0361328125, 'screen': 'RegisterScreen'}
# {'z': 0.580078125, 'y': 0.8125, 'x': 0.0419921875, 'screen': 'RegisterScreen'}
# {'z': 0.5751953125, 'y': 0.8125, 'x': 0.0390625, 'screen': 'RegisterScreen'}
# {'z': 0.669921875, 'y': 0.7529296875, 'x': -0.0341796875, 'screen': 'RegisterScreen'}
# {'z': 0.673828125, 'y': 0.748046875, 'x': -0.025390625, 'screen': 'RegisterScreen'}
# {'z': 0.673828125, 'y': 0.75390625, 'x': -0.03125, 'screen': 'RegisterScreen'}
# {'z': 0.6640625, 'y': 0.755859375, 'x': -0.01953125, 'screen': 'RegisterScreen'}
# {'z': 0.65234375, 'y': 0.755859375, 'x': -0.015625, 'screen': 'RegisterScreen'}
# {'z': 0.6640625, 'y': 0.7548828125, 'x': -0.021484375, 'screen': 'RegisterScreen'}
# {'z': 0.6630859375, 'y': 0.7607421875, 'x': -0.0205078125, 'screen': 'RegisterScreen'}
# {'z': 0.654296875, 'y': 0.7529296875, 'x': -0.0234375, 'screen': 'RegisterScreen'}
# {'z': 0.6669921875, 'y': 0.7421875, 'x': -0.01171875, 'screen': 'RegisterScreen'}
# {'z': 0.666015625, 'y': 0.7490234375, 'x': -0.0234375, 'screen': 'RegisterScreen'}
# {'z': 0.6630859375, 'y': 0.7431640625, 'x': -0.0126953125, 'screen': 'RegisterScreen'}

# %% [markdown]
# | Inicio da criação da analize de quantificação e time Stemp |
#
# y = lista dos nomes dos usuarios
#
# names_to_skip = filtragem dos dados por nome
#
# number = ""
#
# sem, z = limpagem de nome apenas
#
# all_files = leitura dos arquivos
#
# todos = lista de todos os usuarios sem o timestemp

# %%
all_files = glob.glob('sensors/*_*.json')
y = []
names_to_skip = []
number = []
todos =[]
x = 0
for file in all_files:
    name = file.split('\\')[1].split('.')[0]
    first_name = name.split('_')[0]
    sem = name.split('_')[0]
    todos.append(sem)
    if first_name not in names_to_skip:
        names_to_skip.append(first_name)
        x=x+1
        z = name.split('_')[0]
        y.append(z)

# %%
len(y)
# Out:
# 1132

# %% [markdown]
# | Criar a lista de da quantidade repetida de cada usuario |
#
# utilizando o repeat para visualizar em 'y' os nomes de usuarios e contar comparando com os valores em 'todos'

# %%
count = 0
lista = []
for repeat in y:
    contagem = todos.count(repeat)
    lista.append(contagem)

# %% [markdown]
# | Criar extensão da lista de usuario e quantidade de times stemp |
#
# Cada sample da timestemp é tirada entre 15-20 ms
#
# extenção = lista matriz usuario e quantidade
#
#
# cria arquivo quantidade de timestemp

# %%
from itertools import zip_longest
extencao = list(zip_longest(y, lista, fillvalue=''))
extencao

with open(r'quantidade de arquivos.txt', 'w') as fp:
    for item in extencao:
        fp.write("%s %i\n" % item)
print('Done')
# Out:
# Done

# %%
extencao
# Out:
# [('00qhiaz', 77),
#  ('043lwou', 34),
#  ('054r5r7', 6),
#  ('06mdn3c', 507),
#  ('0c87n4d', 38),
#  ('0ddm38', 52),
#  ('0dhpckv', 1),
#  ('0e49nrq', 2),
#  ('0ew8zgp', 8),
#  ('0f4uezb', 1),
#  ('0ge7rd5', 15),
#  ('0hz8270', 66),
#  ('0irsvx7', 76),
#  ('0k2yiu3', 4),
#  ('0k77as7', 38),
#  ('0kjevf3', 132),
#  ('0ku7bb', 70),
#  ('0lnmasb', 19),
#  ('0mmpa11', 50),
#  ('0n1ewpo', 11),
#  ('0o2grk2', 272),
#  ('0pe7mrz', 43),
#  ('0sl48ao', 6),
#  ('0sqy7ba', 260),
#  ('0t7sulk', 42),
#  ('0u0m6ev', 29),
#  ('0xbcxal', 122),
#  ('0yjaom5', 15),
#  ('0yx7i56', 1),
#  ('0z75cgk', 2),
#  ('0z9xv36', 430),
#  ('0zb4hq6', 36),
#  ('0zh8j1j', 29),
#  ('11gi9t1', 2),
#  ('11q2156', 2),
#  ('141kag5', 13),
#  ('148r1k5', 129),
#  ('1519dl3', 36),
#  ('153lbz0', 22),
#  ('15g70vg', 18),
#  ('15rgvo5', 3),
#  ('179xxyt', 3),
#  ('186fa7r', 2),
#  ('19csc5u', 9),
#  ('1byb26i', 2),
#  ('1dip0jt', 1),
#  ('1gnhe9f', 12),
#  ('1i8msn6', 9),
#  ('1ii3q4u', 36),
#  ('1irc2tz', 3),
#  ('1jtpm7m', 6),
#  ('1ju487l', 8),
#  ('1k591ui', 2),
#  ('1krn0b7', 35),
#  ('1kxyonp', 13),
#  ('1l27eth', 6),
#  ('1l967s6', 143),
#  ('1ljg3w5', 5),
#  ('1m2heyf', 37),
#  ('1n3nfhx', 38),
#  ('1nc8tx7', 8),
#  ('1o6wzr7', 11),
#  ('1oekg57', 7),
#  ('1p8vgbm', 28),
#  ('1pboqyx', 7),
#  ('1sh5k9p', 3),
#  ('1tnew6a', 1),
#  ('1uep0cy', 80),
#  ('1v3m00i', 9),
#  ('1v7m67q', 10),
#  ('1w8zqr6', 8),
#  ('1xtyxr', 25),
#  ('1y7jz3u', 20),
#  ('1yrvs4j', 5),
#  ('21t7ra3', 108),
#  ('26weoqg', 85),
#  ('28hotg0', 4),
#  ('28sxfuh', 18),
#  ('2aafc7w', 3),
#  ('2bv2c7c', 790),
#  ('2cf0s6s', 29),
#  ('2end92', 71),
#  ('2h2o0iz', 79),
#  ('2haj89', 42),
#  ('2i1g2ws', 5),
#  ('2j4qo8i', 44),
#  ('2j4z1mf', 14),
#  ('2jih4e2', 11),
#  ('2mvvp5v', 4),
#  ('2o16sv1', 25),
#  ('2p0z7hy', 38),
#  ('2pfhq5j', 27),
#  ('2uz6jv0', 13),
#  ('2vv6lsy', 1),
#  ('2wwrh4n', 26),
#  ('2x48i0l', 80),
#  ('2zy9hqf', 13),
#  ('3031jd7', 25),
#  ('31lodcb', 27),
#  ('31punba', 18),
#  ('33a3a5u', 478),
#  ('33twksh', 49),
#  ('35mla5s', 26),
#  ('36vky36', 60),
#  ('36wyfox', 12),
#  ('36z77qn', 61),
#  ('388k8rf', 3),
#  ('38muxp3', 5),
#  ('39mowwy', 4),
#  ('3cd5kys', 2),
#  ('3e6o7ih', 118),
#  ('3f2txh', 1),
#  ('3fgvdg', 23),
#  ('3hodyn3', 52),
#  ('3i2at74', 34),
#  ('3inxcyi', 55),
#  ('3kei971', 23),
#  ('3m2ih7d', 64),
#  ('3pfs6u', 16),
#  ('3pmv9aq', 313),
#  ('3pttjjp', 2),
#  ('3qiir7', 39),
#  ('3qz8lsk', 53),
#  ('3r00qnp', 5),
#  ('3siujrj', 102),
#  ('3ukdxyw', 2),
#  ('3vkbinh', 5),
#  ('3xhmhs7', 75),
#  ('3xuaoif', 12),
#  ('3ypgstx', 221),
#  ('3zd4fdk', 307),
#  ('401m360', 40),
#  ('43ndomr', 20),
#  ('44sopa5', 80),
#  ('45bztpu', 2),
#  ('47o61zm', 12),
#  ('4abtgub', 73),
#  ('4arhrqa', 1),
#  ('4cdtwuq', 9),
#  ('4dz53zb', 4),
#  ('4fgo39z', 2),
#  ('4fjfjlm', 189),
#  ('4fzxrla', 70),
#  ('4gaigra', 21),
#  ('4gpfvf', 150),
#  ('4hpr6ii', 34),
#  ('4iyf23v', 11),
#  ('4l9kvp8', 114),
#  ('4my64pv', 35),
#  ('4nlvqat', 82),
#  ('4o8cham', 177),
#  ('4osohgf', 75),
#  ('4ph2qr', 74),
#  ('4pxr7gt', 26),
#  ('4rk17kc', 1),
#  ('4sl0lpa', 3),
#  ('4su8oxl', 64),
#  ('4t2hrlb', 14),
#  ('4uk8ff', 114),
#  ('4vxthrz', 7),
#  ('4wjg1p5', 8),
#  ('4xn84bu', 10),
#  ('4zcqkvk', 7),
#  ('4zg9xn0', 21),
#  ('508rk86', 885),
#  ('50nv1kf', 7),
#  ('52cxxgh', 432),
#  ('562ipct', 3),
#  ('568s7tq', 44),
#  ('56zi3vy', 358),
#  ('57226ew', 110),
#  ('58s32rk', 25),
#  ('58zthx2', 8),
#  ('5c9e2i6', 203),
#  ('5dctb61', 5),
#  ('5e1bc0', 46),
#  ('5efx1u9', 5),
#  ('5fue178', 29),
#  ('5g7ljim', 4),
#  ('5gcshmn', 28),
#  ('5hb4oww', 2),
#  ('5hq0j21', 4),
#  ('5i52scp', 1),
#  ('5ig1q0o', 18),
#  ('5ikoz5m', 7),
#  ('5kqq3c5', 9),
#  ('5nlfvm', 69),
#  ('5ode642', 3),
#  ('5opc46', 50),
#  ('5pq9ivb', 22),
#  ('5qxkkho', 36),
#  ('5rgtb1c', 42),
#  ('5rzqw0i', 3),
#  ('5uaozu8', 168),
#  ('5wo25jp', 72),
#  ('5ypuhoh', 5),
#  ('609x840', 25),
#  ('60u0i9n', 358),
#  ('64c7vat', 5),
#  ('64sqv7e', 20),
#  ('654f8mn', 1),
#  ('6671xdz', 1),
#  ('677l8bq', 399),
#  ('682w4g', 23),
#  ('68d09fm', 2),
#  ('68n9ll', 786),
#  ('68xjyb8', 39),
#  ('69gwr8f', 13),
#  ('69rcnv2', 16),
#  ('6aid7h3', 4),
#  ('6cd4h1g', 64),
#  ('6g52gtp', 2),
#  ('6ikjpwj', 7),
#  ('6iqiw11', 5),
#  ('6jtbpdh', 288),
#  ('6krti38', 9),
#  ('6qrtzb2', 1),
#  ('6thpz6', 61),
#  ('6v1elkv', 14),
#  ('6v3c51r', 1),
#  ('70x0gse', 13),
#  ('71d7p4m', 28),
#  ('7382bh9', 27),
#  ('75bld6r', 33),
#  ('75rm4k8', 7),
#  ('777kjeh', 6),
#  ('7f0qwx8', 219),
#  ('7fn7udw', 17),
#  ('7fvjaa2', 15),
#  ('7g925ld', 57),
#  ('7g9q4ej', 38),
#  ('7glhxm6', 2),
#  ('7hxf3wx', 10),
#  ('7jnd6mb', 2),
#  ('7jos4ax', 32),
#  ('7ksck80', 222),
#  ('7lbvlpl', 186),
#  ('7mcbsd8', 14),
#  ('7mgzdbn', 2),
#  ('7nv0i9p', 195),
#  ('7p7z5ex', 47),
#  ('7pyku23', 7),
#  ('7rwbuzl', 26),
#  ('7spt4xp', 10),
#  ('7stgp0r', 803),
#  ('7u5klrb', 1),
#  ('7uiwwkc', 23),
#  ('7vs9ux1', 20),
#  ('7x6znh6', 3),
#  ('7ybyhho', 5),
#  ('7ydx7lo', 5),
#  ('7znx8wf', 12),
#  ('819qox2', 4),
#  ('837kte9', 125),
#  ('83mc8p', 3),
#  ('83oausk', 48),
#  ('855whqe', 110),
#  ('87g7ege', 44),
#  ('885yvsc', 10),
#  ('88ixhgt', 32),
#  ('8aaazt3', 32),
#  ('8atitz', 38),
#  ('8bi324', 1),
#  ('8euk4lj', 4),
#  ('8evvakn', 5),
#  ('8kq9h4j', 65),
#  ('8mbv7x1', 6),
#  ('8qmyi66', 23),
#  ('8qpgog', 55),
#  ('8qpkrfo', 57),
#  ('8qumojw', 6),
#  ('8qwsx21', 93),
#  ('8ru47ql', 50),
#  ('8rx94ay', 6),
#  ('8uohdv4', 533),
#  ('8wkh5tr', 9),
#  ('8xjh8a', 1040),
#  ('8y2ladt', 4),
#  ('8ydfa4w', 10),
#  ('8yx8q4t', 48),
#  ('901o8hq', 79),
#  ('9035a6t', 33),
#  ('90678mi', 13),
#  ('91fs9wa', 30),
#  ('92uf4uc', 8),
#  ('949bzfb', 5),
#  ('96arigv', 20),
#  ('97bfvo4', 10),
#  ('98spl5x', 12),
#  ('99exci4', 11),
#  ('99v5xo8', 4),
#  ('9a30k9c', 24),
#  ('9b6tv8', 2),
#  ('9d2syys', 42),
#  ('9d8b9n7', 38),
#  ('9e0qbp', 27),
#  ('9gx7uks', 217),
#  ('9gykp6g', 7904),
#  ('9i2pt7y', 37),
#  ('9jiir43', 1),
#  ('9mxt26y', 19),
#  ('9p07vq2', 7),
#  ('9q4nmh8', 55),
#  ('9rhufeh', 32),
#  ('9s6m16t', 9),
#  ('9saxhys', 54),
#  ('9sxtiev', 149),
#  ('9umr1fl', 2),
#  ('9wami0o', 3),
#  ('9wlqdxo', 24),
#  ('9yg825n', 40),
#  ('9ysxpim', 10),
#  ('9yzf1nd', 4),
#  ('9z8hm89', 73),
#  ('9zb79o2', 31),
#  ('9zy9ysf', 88),
#  ('a1bl61l', 20),
#  ('a2f0a5h', 4),
#  ('a30ggtf', 38),
#  ('a3tlk3w', 4),
#  ('a49ifaj', 52),
#  ('a4a7zxx', 13),
#  ('a4xujm0', 15),
#  ('a5dxj7u', 2),
#  ('a6kw4yu', 23),
#  ('a764j4x', 79),
#  ('a91sek', 29),
#  ('a94cv8', 23),
#  ('aa5jxb', 5),
#  ('aa9mfhd', 12),
#  ('aailf3e', 2),
#  ('adj01eb', 72),
#  ('ae0l7tj', 26),
#  ('aekrml7', 179),
#  ('agmp5h7', 126),
#  ('aiv5gy0', 4),
#  ('ajmwr7a', 124),
#  ('al56j8j', 25),
#  ('alcfj3x', 74),
#  ('aon5ow1', 55),
#  ('ap1oez8', 182),
#  ('apkn1e4', 24),
#  ('appqwv6', 3),
#  ('aql887a', 86),
#  ('aqq25vq', 303),
#  ('ar51tm5', 8),
#  ('askiftq', 3),
#  ('atdolqt', 188),
#  ('atox7qd', 7),
#  ('avl7e5t', 7),
#  ('avudrey', 148),
#  ('awuyoi1', 2),
#  ('ax4mapr', 18),
#  ('azd3rx0', 27),
#  ('azm8u3z', 10),
#  ('b0602fr', 820),
#  ('b0zirro', 80),
#  ('b18qyab', 16),
#  ('b1qt6gb', 102),
#  ('b40mg3b', 54),
#  ('b4dnqru', 1),
#  ('b4f68ey', 2),
#  ('b4lcs16', 189),
#  ('b7hbdg1', 9),
#  ('b8g4bl5', 153),
#  ('b9dujd', 323),
#  ('bady2td', 11),
#  ('bafylx9', 4),
#  ('bfrbx0n', 85),
#  ('bg0zl2s', 2),
#  ('bh4vm6o', 105),
#  ('biysamt', 254),
#  ('bjqkz1y', 21),
#  ('bjznxam', 9),
#  ('bnrxpzi', 6),
#  ('bo9mhqr', 537),
#  ('bqwut29', 313),
#  ('brqm3dt', 4),
#  ('bskrvba', 2),
#  ('bu0z5eh', 13),
#  ('bxczvfe', 67),
#  ('bxqvd99', 12),
#  ('c04c5mf', 26),
#  ('c1xd1cj', 3),
#  ('c2mza2d', 3),
#  ('c86v4rg', 149),
#  ('c8wbz3m', 34),
#  ('cd9njdd', 7),
#  ('cdaf89z', 47),
#  ('cdbbn96', 37),
#  ('cekd2br', 8),
#  ('cfmwho3', 62),
#  ('ch0f2eh', 7),
#  ('chcey24', 14),
#  ('ckeheu7', 3),
#  ('cla7os9', 23),
#  ('cmgw1m8', 3),
#  ('cn1lmwf', 325),
#  ('cn6tet2', 34),
#  ('cntm3vm', 180),
#  ('coowcbf', 10),
#  ('cp1xi2m', 24),
#  ('cp7kjhx', 247),
#  ('cr170mi', 16),
#  ('cusolvy', 17),
#  ('cxfpidu', 31),
#  ('cxsdf3w', 18),
#  ('cye5773', 50),
#  ('cyfxq2q', 156),
#  ('cylwx45', 70),
#  ('cyr6jmc', 37),
#  ('cyrhwj4', 19),
#  ('d32z3b7', 7),
#  ('d45k5rh', 5),
#  ('d4bovm', 348),
#  ('d4ydsnq', 1),
#  ('d515ev3', 13),
#  ('d52s5qy', 1),
#  ('d5deark', 2218),
#  ('d62c3ke', 13),
#  ('d69znzg', 10),
#  ('d99p79w', 222),
#  ('dai60mp', 14),
#  ('ddvax7h', 42),
#  ('debs1l', 187),
#  ('dfq4hu2', 7),
#  ('dghg7h7', 55),
#  ('dici8pg', 1),
#  ('dj20pdi', 155),
#  ('djfqjo2', 40),
#  ('dke6jj9', 21),
#  ('dkhv0os', 63),
#  ('dkz6u0j', 147),
#  ('dlepqpx', 235),
#  ('dlw22as', 31),
#  ('dn5a87', 33),
#  ('do4ltbu', 36),
#  ('dptxc23', 14),
#  ('drq0yh6', 45),
#  ('ds5rn1t', 29),
#  ('ds8ie0z', 13),
#  ('dsgjsr8', 17),
#  ('dsj3ip3', 27),
#  ('du40e9f', 4),
#  ('dxfax7g', 9),
#  ('dz2x3xn', 32),
#  ('e1e1vcb', 22),
#  ('e2qa1w0', 23),
#  ('e3mdbib', 9),
#  ('e3rsf2n', 18),
#  ('e58xlcg', 5),
#  ('e651oif', 1),
#  ('e8c79mk', 456),
#  ('e8e5l3l', 10),
#  ('e8rbsqz', 33),
#  ('ebqa49e', 9),
#  ('ecopr3o', 6),
#  ('edzx35q', 6),
#  ('efg8oyz', 15),
#  ('efm2ddw', 2),
#  ('egkr20w', 56),
#  ('el004dy', 13),
#  ('elvsfr0', 35),
#  ('embd1i8', 25),
#  ('emhjyid', 40),
#  ('eomz1ri', 34),
#  ('erkb957', 46),
#  ('euhfjfq', 25),
#  ('evrd209', 68),
#  ('ewtwqz', 120),
#  ('f0lxlyl', 1),
#  ('f2lvpvm', 2),
#  ('f3mcsv', 47),
#  ('f4tp67x', 1),
#  ('f6acms2', 7),
#  ('f9vvtpx', 17),
#  ('fbgu7ow', 9),
#  ('fbv761e', 46),
#  ('fcaw17y', 41),
#  ('fdpl55', 34),
#  ('feglfhj', 1),
#  ('fhzorw6', 45),
#  ('fit126a', 116),
#  ('fjipq09', 9),
#  ('fktvead', 23),
#  ('fl1wqc', 5),
#  ('flidyt', 6595),
#  ('fn4tvxu', 270),
#  ('foa0oxh', 10),
#  ('fqlhhqg', 11),
#  ('frl4fzq', 2870),
#  ('frz0boj', 135),
#  ('fsui7zb', 237),
#  ('ftk8v41', 731),
#  ('fu1y9x6', 161),
#  ('fuewrpn', 18),
#  ('fugwhqj', 4),
#  ('fyp91kq', 71),
#  ('fzf6j0l', 184),
#  ('g5dfles', 1),
#  ('g5fc9sj', 143),
#  ('g8tgmdj', 3),
#  ('gd8hn84', 100),
#  ('gdt6c3r', 85),
#  ('ge44ogk', 11),
#  ('gfwmpf0', 82),
#  ('gg16nwz', 57),
#  ('ggxoegu', 20),
#  ('ghtlpmi', 21),
#  ('gix1ytt', 18),
#  ('gj27gdx', 9),
#  ('gjnphzk', 9),
#  ('gjxlvqz', 107),
#  ('gk2pzjv', 4),
#  ('go7l7xv', 6),
#  ('goie1a0', 12),
#  ('goixz4l', 16),
#  ('gpjkduv', 91),
#  ('gpky89j', 31),
#  ('gpu843e', 9),
#  ('gqfdnhv', 5),
#  ('grdoale', 29),
#  ('grqbbtw', 41),
#  ('gsf5udg', 29),
#  ('gt4yc1j', 648),
#  ('gv7tmtg', 8),
#  ('gvdktw2', 9),
#  ('gvu7ek9', 9),
#  ('gxsgxb5', 91),
#  ('gxtxj8d', 17),
#  ('gy48qmy', 89),
#  ('gzx7rv', 200),
#  ('h03mw70', 145),
#  ('h0vokx1', 14),
#  ('h0y3w4r', 2),
#  ('h2o2ieg', 152),
#  ('h4ukipn', 5),
#  ('h886ntl', 28),
#  ('h93nh4a', 26),
#  ('ha3ev43', 146),
#  ('hahbthc', 69),
#  ('hb5aeel', 14),
#  ('hcan5xe', 41),
#  ('hd3coj2', 11),
#  ('hfmko75', 3),
#  ('hhhype8', 12),
#  ('hjlnzy8', 11),
#  ('hk9em99', 67),
#  ('hl7odjo', 60),
#  ('hmf35ac', 3),
#  ('hmxs55x', 25),
#  ('houcdda', 16),
#  ('hpiaynu', 5),
#  ('hpuzm3h', 2),
#  ('hq5a13y', 8),
#  ('hqqo4w4', 30),
#  ('hv7o35l', 22),
#  ('hvvzcv5', 1),
#  ('hw2x6kb', 2),
#  ('hw7rn6q', 95),
#  ('hwx9u0h', 50),
#  ('hxaj0fx', 6),
#  ('hyjdvm5', 6),
#  ('hyo6pao', 49),
#  ('i0rvwsh', 46),
#  ('i1bndzt', 12),
#  ('i1zfvsm', 7),
#  ('i371qns', 12),
#  ('i4bklj6', 58),
#  ('i6298h7', 101),
#  ('i63epih', 11),
#  ('i95tojd', 6),
#  ('ia6guq6', 14),
#  ('ibh5wle', 17),
#  ('igojdrb', 6),
#  ('ihh79o3', 13),
#  ('iipes2g', 61),
#  ('ilwx0qp', 14),
#  ('im18fyp', 46),
#  ('io22nan', 10),
#  ('iox1y0w', 22),
#  ('ioxyr9y', 490),
#  ('ip1pofi', 19),
#  ('ipuyiii', 226),
#  ('iq2gdbj', 18),
#  ('ir5ilr0', 21),
#  ('is3spv', 102),
#  ('iu1pg5h', 11),
#  ('iuwuxhe', 5),
#  ('iyw4bhv', 36),
#  ('izbr4dk', 79),
#  ('j0hrnvy', 34),
#  ('j0xfupk', 15),
#  ('j3a4kid', 45),
#  ('j3as74z', 1),
#  ('j54z195', 9),
#  ('j5p35o', 5),
#  ('j5yd4uw', 61),
#  ('j6hhnmt', 45),
#  ('j97ke2q', 3),
#  ('jcih8no', 128),
#  ('jdjhtm2', 102),
#  ('jdlb4nc', 47),
#  ('jed37gc', 5),
#  ('jf9nmty', 106),
#  ('jfmr79c', 17),
#  ('jg1jdra', 2),
#  ('jho7anh', 9),
#  ('ji2hwh', 388),
#  ('jiydsty', 23),
#  ('jjv3xq6', 77),
#  ('jkoiwz7', 27),
#  ('jln9je5', 4),
#  ('jlszmxz', 3),
#  ('jlx3rg4', 1),
#  ('jm7e6k3', 4),
#  ('jpc51ex', 25),
#  ('jptz8sp', 2),
#  ('jtkagmb', 5),
#  ('jtps62', 17),
#  ('junkxkw', 10),
#  ('jw3yf04', 15),
#  ('jwenurj', 29),
#  ('jxcwk52', 25),
#  ('jxs77pu', 16),
#  ('jy3jmug', 230),
#  ('jyi1db', 11),
#  ('jym3rof', 5),
#  ('jzaa9de', 59),
#  ('jzcbdq3', 18),
#  ('jze0zte', 45),
#  ('k0201jv', 31),
#  ('k191nzh', 16),
#  ('k4zwqvj', 18),
#  ('k7z6kfh', 3),
#  ('k80wpn9', 14),
#  ('k8g94cw', 16),
#  ('k99bjw3', 1366),
#  ('k9ptsb2', 369),
#  ('kciklam', 4),
#  ('kgrlt2w', 2),
#  ('khovbl4', 3),
#  ('kir7gs1', 13),
#  ('knki1se', 314),
#  ('kp74uvn', 95),
#  ('kpbebt8', 9),
#  ('kq1uu02', 33),
#  ('kq76a1r', 3),
#  ('kqmsnvb', 1),
#  ('kr0l6cf', 5),
#  ('kvr7idp', 4),
#  ('kw2g2f', 30),
#  ('kwlh67i', 1),
#  ('kwmdya1', 5),
#  ('kxal5d0', 43),
#  ('kychkdu', 12),
#  ('l0mn8ai', 22),
#  ('l0qgb1b', 1),
#  ('l1doqao', 289),
#  ('l2160o2', 5),
#  ('l2cev6n', 64),
#  ('l2wyd64', 4),
#  ('l3fjh1p', 2),
#  ('l3rcqx4', 311),
#  ('l4etbgo', 119),
#  ('l4gmdfp', 78),
#  ('l7awb2f', 5),
#  ('l7pkjen', 55),
#  ('la2ruhs', 3),
#  ('lb6djej', 248),
#  ('lbwzrxs', 10),
#  ('lcirhbh', 7),
#  ('ld9rck', 282),
#  ('ldg6zjk', 741),
#  ('lej2hfo', 100),
#  ('lekxv5r', 69),
#  ('lfqxp4u', 1),
#  ('lfwcsch', 15),
#  ('lgowbxc', 7),
#  ('licbd9y', 11),
#  ('lidr0a8', 3),
#  ('ljuc0xt', 5),
#  ('lk75jrq', 108),
#  ('lkafe7w', 44),
#  ('lm8ujtt', 533),
#  ('lmwnunh', 11),
#  ('lo04gc8', 17),
#  ('lo6pbw5', 2),
#  ('lowjuk', 44),
#  ('lq4b59d', 17),
#  ('lqxz7nk', 1),
#  ('lr1hc61', 5),
#  ('lrcsv8m', 73),
#  ('lrf34sh', 31),
#  ('lsj49oj', 20),
#  ('ltsande', 35),
#  ('lu2vvwm', 2),
#  ('lues3zt', 38),
#  ('lviovtn', 33),
#  ('lvrishm', 1079),
#  ('lvwfjft', 222),
#  ('lwacw1z', 127),
#  ('lz6lxw3', 77),
#  ('m118shg', 36),
#  ('m4k0ppn', 1),
#  ('m4urjh0', 77),
#  ('m5nq6la', 349),
#  ('m7ftjmd', 3),
#  ('m7ufkzi', 39),
#  ('m7uqrnv', 162),
#  ('m8luyig', 225),
#  ('mbkmuyy', 2),
#  ('mbppqch', 3),
#  ('meakc9c', 124),
#  ('mevuzg', 20),
#  ('mf1i1kh', 4),
#  ('mfe5h8z', 20),
#  ('mfg63ja', 1),
#  ('mixtfy4', 15),
#  ('miz1q0f', 15),
#  ('mj0h3t6', 6),
#  ('mmdljwx', 4),
#  ('mn1ciwi', 4),
#  ('mo16dbv', 53),
#  ('mo4pn9h', 9),
#  ('mp34rny', 40),
#  ('mpo0d8g', 17),
#  ('mpsa2t5', 17),
#  ('mpzdxog', 48),
#  ('mqkqbdu', 45),
#  ('mrha8cm', 41),
#  ('myamnsr', 3),
#  ('mytmnjg', 84),
#  ('mzbrwfo', 3),
#  ('mzp2yvb', 8),
#  ('n0g0zsv', 703),
#  ('n1eockt', 17),
#  ('n2y3cv2', 11),
#  ('n38l2kc', 56),
#  ('n3xbejs', 46),
#  ('n4vfsba', 277),
#  ('n7ml8hx', 385),
#  ('nbd9fus', 156),
#  ('nc1dg7', 39),
#  ('ncb5eqe', 6),
#  ('ne1igm6', 54),
#  ('ne3hq8e', 13),
#  ('nez16yn', 16),
#  ('ng40e6', 17),
#  ('njxs8d6', 35),
#  ('nkqvh04', 17),
#  ('nkzlv6k', 21),
#  ('nlqgug8', 18),
#  ('nn8bses', 58),
#  ('nnoz74j', 40),
#  ('npd5hc2', 22),
#  ('nptgvt4', 7),
#  ('nqkmwdf', 12),
#  ('nrr2gja', 114),
#  ('nrvij9h', 4),
#  ('ntgje0f', 11),
#  ('ntmyzk2', 99),
#  ('nvxrplm', 1),
#  ('nxk23ci', 4),
#  ('nz9eg12', 2),
#  ('o0fkbgn', 47),
#  ('o16roh6', 285),
#  ('o1m9hgs', 40),
#  ('o1v59jb', 35),
#  ('o2loi82', 3),
#  ('o3auaic', 49),
#  ('o3h7qpg', 27),
#  ('o4fves2', 7),
#  ('o54bzhz', 12),
#  ('o5guqph', 11),
#  ('o6fd5e8', 45),
#  ('o6g2zef', 1236),
#  ('o6k3gka', 5),
#  ('o79ddht', 13),
#  ('o9pmjyj', 8),
#  ('objhw1u', 15),
#  ('oc0s469', 69),
#  ('odqnjbd', 6),
#  ('of25spi', 97),
#  ('ofja9h8', 14),
#  ('ohvwuz7', 2),
#  ('oi35sdw', 114),
#  ('oicjg55', 12),
#  ('oim4cbv', 3),
#  ('oio09w4', 3),
#  ('oipm6b4', 31),
#  ('ok31npy', 106),
#  ('ol2hwt5', 11),
#  ('olkizm4', 2),
#  ('olxsgno', 168),
#  ('omaw5mr', 26),
#  ('onw5b1u', 5),
#  ('ooq9btt', 1),
#  ('oq3fk1y', 16),
#  ('ot2pdyv', 38),
#  ('otu8x88', 260),
#  ('ou5l8dc', 8),
#  ('ow9ub19', 30),
#  ('oww9ekr', 32),
#  ('p0lkii9', 52),
#  ('p1h97hu', 7),
#  ('p1khll5', 2),
#  ('p36nqpc', 23),
#  ('p3mbvhp', 134),
#  ('p3pxp6', 62),
#  ('p4h1t65', 71),
#  ('p581j6a', 4),
#  ('p6m6foz', 59),
#  ('p8gwaon', 5),
#  ('p919q7d', 44),
#  ('p9dg8v5', 36),
#  ('pa3bgd1', 6),
#  ('pchp3fw', 25),
#  ('pdhf5c0', 16),
#  ('pemzvif', 40),
#  ('pf3v1xv', 195),
#  ('pgfm0e5', 1),
#  ('ph4ly9f', 10),
#  ('picvmz6', 5),
#  ('pjb3q24', 57),
#  ('pkpe5hx', 29),
#  ('pks0ilv', 15),
#  ('pkxaeru', 7),
#  ('pl0w3c5', 20),
#  ('plfzjjx', 1),
#  ('pnuvvv9', 23),
#  ('ppgo59j', 93),
#  ('pqjmv8m', 29),
#  ('pqueqp', 18),
#  ('pqunrw', 93),
#  ('ps3mhtf', 53),
#  ('psspid6', 41),
#  ('ptsbkh', 97),
#  ('puukg3', 30),
#  ('pv8zc9h', 120),
#  ('pxipu7n', 447),
#  ('pxo0n7t', 12),
#  ('pyl4mrc', 48),
#  ('q0hdqhs', 13),
#  ('q2i3ehh', 17),
#  ('q59ppvq', 28),
#  ('q6i3mes', 18),
#  ('q7fjau8', 4),
#  ('q7jmq47', 43),
#  ('q8yhnxk', 22),
#  ('q9tn370', 6),
#  ('qa94pwy', 304),
#  ('qc9hlk5', 109),
#  ('qd1umv', 117),
#  ('qdnxabg', 14),
#  ('qgv2hd2', 107),
#  ('qj2jufi', 76),
#  ('qjip2kj', 36),
#  ('qna4v9w', 72),
#  ('qsuh63a', 16),
#  ('qy10wbn', 182),
#  ('r05vewv', 1),
#  ('r0y6x9j', 139),
#  ('r13q05q', 238),
#  ('r1j72d4', 8),
#  ('r2p4ljs', 405),
#  ('r370zed', 54),
#  ('r43g4z9', 14),
#  ('r4f0y59', 7),
#  ('r6ei6zy', 323),
#  ('r6j7gof', 4),
#  ('r883oye', 1),
#  ('r92spr6', 1),
#  ('r9ptgp2', 44),
#  ('r9xa1gr', 10),
#  ('ra7gphc', 9),
#  ('rb8juo0', 6),
#  ('rcuqzrh', 413),
#  ('rfagb10', 84),
#  ('rfkmbfy', 25),
#  ('rhd6g5o', 77),
#  ('rl6f1vc', 8),
#  ('rlvzek7', 98),
#  ('rm1zbjm', 34),
#  ('rn7miix', 40),
#  ('rnhwbot', 67),
#  ('rnnpvrw', 4),
#  ('rq48pbx', 17),
#  ('rqzcqxm', 2),
#  ('rr1flci', 28),
#  ('rrcj8kw', 50),
#  ('rs28ffy', 21),
#  ('rsgubi', 539),
#  ('rvy0vfd', 55),
#  ('rwtux9z', 10),
#  ('rxu4yqp', 119),
#  ('rz1gjdt', 9),
#  ('rzau2qk', 8),
#  ('s0xn208', 6),
#  ('s1lnbqu', 8),
#  ('s1mvca', 9),
#  ('s2o8tng', 40),
#  ('s4blagq', 10),
#  ('s539u6s', 55),
#  ('samv2zn', 17),
#  ('scokepp', 7),
#  ('sgio5vp', 5),
#  ('siw3zbm', 53),
#  ('sjz362j', 14),
#  ('smzipee', 3),
#  ('snjckn1', 32),
#  ('sparnjp', 3),
#  ('sqhkewt', 62),
#  ('srekxpz', 1),
#  ('ss83smv', 51),
#  ('suwvoda', 3),
#  ('sx9u29m', 11),
#  ('sxvkh3b', 403),
#  ('sxxukyx', 38),
#  ('sxzboz9', 39),
#  ('sy0ojxv', 24),
#  ('szmkl5t', 377),
#  ('t0p185n', 1),
#  ('t0vdn4', 48),
#  ('t151sy9', 4),
#  ('t1f6orl', 13),
#  ('t200zqb', 3),
#  ('t2bp2j', 4),
#  ('t32j50o', 2),
#  ('t4c8ve7', 76),
#  ('t4l7hpb', 34),
#  ('t52p851', 17),
#  ('t8ko1gq', 57),
#  ('ta0ko40', 527),
#  ('tdz6i2b', 217),
#  ('tho1k68', 59),
#  ('ti0yq16', 11),
#  ('tlamfnx', 8),
#  ('tlgnz4w', 19),
#  ('tqv70di', 34),
#  ('trftjbe', 3),
#  ('tsvmdvu', 26),
#  ('tuvemg', 369),
#  ('tvdcmng', 37),
#  ('txxrlzc', 273),
#  ('u0b80y5', 10),
#  ('u1cvt5', 34),
#  ('u1em5s', 16),
#  ('u29cq2s', 2),
#  ('u3ulou0', 103),
#  ('u4ufm8', 175),
#  ('u58vldq', 2),
#  ('u6foog3', 86),
#  ('u773jxv', 152),
#  ('u8tsq4m', 4),
#  ('u9itn0j', 41),
#  ('u9vm33v', 29),
#  ('uedx6o1', 16),
#  ('ufc6wkn', 6),
#  ('ugf4jvy', 86),
#  ('uidvv9g', 4),
#  ('ulsk0n2', 5),
#  ('uoaney9', 21),
#  ('uoicvud', 42),
#  ('uqxqo92', 2),
#  ('us48gmq', 84),
#  ('usatz0x', 938),
#  ('usg67d3', 8),
#  ('ut67hyf', 34),
#  ('utuh52t', 39),
#  ('uui53he', 539),
#  ('uvzm1bq', 69),
#  ('uxdav5d', 7),
#  ('uxe6tik', 4),
#  ('uzip5ke', 5229),
#  ('uzl3kvo', 81),
#  ('v1mga89', 64),
#  ('v1t5yl6', 3),
#  ('v2x6zpt', 170),
#  ('v34okg1', 3),
#  ('v596phf', 120),
#  ('v7wrmv5', 59),
#  ('v8gkfvj', 12),
#  ('v90gnf6', 1388),
#  ('va0ijeg', 6),
#  ('vc2w4ls', 12),
#  ('vf8gzhj', 42),
#  ('vicipbn', 386),
#  ('vk43uke', 332),
#  ('vk6arbn', 9),
#  ('vl8q5r5', 13),
#  ('vnl59zq', 4),
#  ('vnskmhb', 58),
#  ('vo441ru', 257),
#  ('vqksv8r', 20),
#  ('vsi7c95', 14),
#  ('vtgthyu', 43),
#  ('vwf0vck', 16),
#  ('vwwvcvp', 52),
#  ('vxhodr9', 57),
#  ...]

# %% [markdown]
# | Quantidade total dos dados |
# contador = contar o valor total no objeto 'lista'

# %%
contador = 0
for help in lista:
    contador = contador + help
contador
# Out:
# 101065

# %% [markdown]
# | Plotagem do graficos useer e quantidade de timeStemp. |
#
# o = é uma lista semelhante apenas de quantificação para o valor total (pode ser retirado)
# "jacare" é so o nome do for

# %%
import matplotlib.pyplot as plt
o = []
for jacare in y:
    cara =cara +1
    o.append(cara) 
plt.plot(o,lista)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
count = 0
duvak = lista
hentai = []
for repeated in lista:
    contagem = duvak.count(repeated)
    hentai.append(contagem)

# %% [markdown]
# | CRIAR TXT DE CADA USUARIO POR QUANTIDADE DE TIMESTEMP |

# %%
pf = pd.read_csv('quantidade de arquivos.txt', sep =" ")
pf
for zero in lista:
    new = pf.loc[pf['quantidade_timestemp'] == zero]
    val = len(new)
    tam =str(val)
    nominho = str(zero)

    with open(r''+tam+ 'users '+ nominho +'timers.txt', 'w') as fp:
        fp.write(str(new))
# Out:
# 5
# 13
# 27
# 1
# 11
# 5
# 52
# 56
# 26
# 52
# 14
# 2
# 3
# 49
# 11
# 2
# 3
# 7
# 7
# 22
# 1
# 5
# 27
# 2
# 9
# 13
# 1
# 14
# 52
# 56
# 1
# 9
# 13
# 56
# 56
# 23
# 1
# 9
# 10
# 16
# 53
# 53
# 56
# 29
# 56
# 52
# 19
# 29
# 9
# 53
# 27
# 26
# 56
# 8
# 23
# 27
# 2
# 45
# 7
# 11
# 26
# 22
# 299   9jiir43                     1
# 360   b4dnqru                     1
# 415   d4ydsnq                     1
# 417   d52s5qy                     1
# 427   dici8pg                     1
# 451   e651oif                     1
# 470   f0lxlyl                     1
# 473   f4tp67x                     1
# 480   feglfhj                     1
# 499   g5dfles                     1
# 557   hvvzcv5                     1
# 594   j3as74z                     1
# 614   jlx3rg4                     1
# 648   kqmsnvb                     1
# 652   kwlh67i                     1
# 657   l0qgb1b                     1
# 676   lfqxp4u                     1
# 690   lqxz7nk                     1
# 704   m4k0ppn                     1
# 717   mfg63ja                     1
# 762   nvxrplm                     1
# 797   ooq9btt                     1
# 821   pgfm0e5                     1
# 829   plfzjjx                     1
# 861   r05vewv                     1
# 871   r883oye                     1
# 872   r92spr6                     1
# 913   srekxpz                     1
# 922   t0p185n                     1
# 1040  x5z8t9c                     1
# 1047  xamvmms                     1
# 1084  yenehau                     1
# 1086  ylocu2a                     1
# 1094  yv6n8gx                     1
# 1114  zcmg3s9                     1
# 1131  zyt437w                     1

# %% [markdown]
# | preguiça de pensar um codigo para estrair do dataframe |

# %%
onestemp1 =['0dhpckv', '0f4uezb','0yx7i56','1dip0jt','1tnew6a','2vv6lsy','3f2txh','4arhrqa','4rk17kc','5i52scp','654f8mn','6671xdz','6qrtzb2','6v3c51r','7u5klrb','8bi324','9jiir43','b4dnqru','d4ydsnq','d52s5qy','dici8pg','e651oif','f0lxlyl','f4tp67x','feglfhj','g5dfles','hvvzcv5','j3as74z','jlx3rg4','kqmsnvb','kwlh67i','l0qgb1b','lfqxp4u','lqxz7nk','m4k0ppn','mfg63ja','nvxrplm','ooq9btt','pgfm0e5','plfzjjx','r05vewv','r883oye','r92spr6','srekxpz','t0p185n','x5z8t9c','xamvmms','yenehau','ylocu2a','yv6n8gx','zcmg3s9','zyt437w']
len(onestemp1)
# Out:
# 52

# %% [markdown]
# | Leitura de json e retirada do tamanho das samples |

# %%
tentando = []
all_files = glob.glob('sensors/*_*.json')
for file in all_files:
    name = file.split('_')[1]
    jon = name.split('.')[0]
    tentando.append(jon)

# %%
len(tentando)
f = open('sensors/0yx7i56_1549297833161.json')
data = json.load(f)
df = pd.DataFrame(data['gyroscope'])

# %%
q_samplegy =[]
q_sampleacc =[]
q = 0
h = 0
b=0

for i in onestemp1:
    for j in tentando:
        json_files = glob.glob('sensors/'+i+'_'+j+'.json')
        for file in json_files:
            x = 'sensors/'+i+'_'+j+'.json'
            if  x == file:
                b = b+1
                h = b/52
                print(h,"%")
                f = open('sensors/'+i+'_'+j+'.json')
                data = json.load(f)
                df = pd.DataFrame(data['gyroscope'])
                q = len(df)
                q_samplegy.append(q)
                df = pd.DataFrame(data['accelerometer'])
                q = len(df)
                q_sampleacc.append(q)
# Out:
# 0.019230769230769232 %
# 0.038461538461538464 %
# 0.057692307692307696 %
# 0.07692307692307693 %
# 0.09615384615384616 %
# 0.11538461538461539 %
# 0.1346153846153846 %
# 0.15384615384615385 %
# 0.17307692307692307 %
# 0.19230769230769232 %
# 0.21153846153846154 %
# 0.23076923076923078 %
# 0.25 %
# 0.2692307692307692 %
# 0.28846153846153844 %
# 0.3076923076923077 %
# 0.3269230769230769 %
# 0.34615384615384615 %
# 0.36538461538461536 %
# 0.38461538461538464 %
# 0.40384615384615385 %
# 0.4230769230769231 %
# 0.4423076923076923 %
# 0.46153846153846156 %
# 0.4807692307692308 %
# 0.5 %
# 0.5192307692307693 %
# 0.5384615384615384 %
# 0.5576923076923077 %
# 0.5769230769230769 %
# 0.5961538461538461 %
# 0.6153846153846154 %
# 0.6346153846153846 %
# 0.6538461538461539 %
# 0.6730769230769231 %
# 0.6923076923076923 %
# 0.7115384615384616 %
# 0.7307692307692307 %
# 0.75 %
# 0.7692307692307693 %
# 0.7884615384615384 %
# 0.8076923076923077 %
# 0.8269230769230769 %
# 0.8461538461538461 %
# 0.8653846153846154 %
# 0.8846153846153846 %
# 0.9038461538461539 %
# 0.9230769230769231 %
# 0.9423076923076923 %
# 0.9615384615384616 %
# 0.9807692307692307 %
# 1.0 %

# %%
len(q_samplegy)
# Out:
# 52

# %%
newlist = list(zip_longest(onestemp1, q_samplegy, fillvalue=''))
newlist = list(zip_longest(newlist, q_sampleacc, fillvalue=''))
with open(r'sample gyroscope and acc.txt', 'w') as fp:
    for item in newlist:
        fp.write("%s %i\n" % item)
print('Done')
# Out:
# Done

# %% [markdown]
# |Criar dataframe com valores da tiragem com accelerometro e gyroscopio|
#
# São retirados os usuarios: 0yx7i56, 1dip0jt, 4arhrqa, 4rk17kc, 5i52scp, 8bi324, e651oif, f0lxlyl, jlx3rg4, ooq9btt, r883oye, r92spr6, zcmg3s9;
#
# Sobram 38 usuarios
#
# Criação do dataframe 'zeta' com a filtragem

# %%
data = pd.read_csv('sample gyroscope and acc.txt', sep =" ")
zeta = data.loc[data['sample_gy'] >= 1]
count = 0
beta = q_samplegy
alfa = []
for repeated in q_samplegy:
    contagem = beta.count(repeated)
    alfa.append(contagem)
len(alfa)
# Out:
# 52

# %%
zeta.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# | Criar txt por quantidade de Samples |

# %%
for zero in q_samplegy:
    new = zeta.loc[zeta['sample_gy'] == zero]
    val = len(new)
    tam =str(val)
    nominho = str(zero)

    with open(r''+tam+ 'users '+ nominho +'samples.txt', 'w') as fp:
        fp.write(str(new))

# %% [markdown]
# | criar analize do menor numero de samples |
#
# User ylocu2a com 141 samples o que dão por volta de 2,8 segundos;
#
# Sera utilizado como media para o grupo inteiro usar 141 samples.

# %%
f = open('sensors/ylocu2a_1542982220706.json')
ylocu2a = json.load(f)
ylocu2af = pd.DataFrame(ylocu2a['gyroscope'])
ylocu2af.drop(["screen"], axis=1, inplace=True)
x = ylocu2af[["x"]]
y = ylocu2af[["y"]]
z = ylocu2af[["z"]]
ax = ylocu2af.plot(linewidth=1, fontsize=10)
# Additional customizations
ax.set_xlabel('Date')
ax.legend(fontsize=12)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = plt.axes(projection='3d')

# Data for a three-dimensional line

ax.plot3D(x, y, z, 'blue')

# Data for three-dimensional scattered points
